# %%
import pandas as pd
weather = pd.read_csv("mandya dataset.csv")
weather
# Out:
#       YEAR  DOY     T2M  T2MDEW  T2M_MAX  T2M_MIN    RH2M  PRECTOTCORR  \
# 0     2001    6   21.28   12.01    30.22    15.45   63.25         0.00
# 1     2001    7   20.63   12.01    29.75    13.65   64.31         0.00
# 2     2001    8   20.81   12.02    29.36    14.08   63.75         0.00
# 3     2001    9   22.18   14.13    30.12    15.39   65.56         0.00
# 4     2001   10   22.83   15.27    30.69    16.46   66.31         0.00
# ...    ...  ...     ...     ...      ...      ...     ...          ...
# 8726  2024  332   21.12   19.08    25.68    17.75   88.88         0.15
# 8727  2024  333   19.98   16.70    26.01    16.19   82.62         1.54
# 8728  2024  334 -999.00 -999.00  -999.00  -999.00 -999.00      -999.00
# 8729  2024  335 -999.00 -999.00  -999.00  -999.00 -999.00      -999.00
# 8730  2024  336 -999.00 -999.00  -999.00  -999.00 -999.00      -999.00
#
#         WS2M  WS2M_MAX  WS2M_MIN  GWETTOP   Place
# 0       2.34      3.80      1.30     0.57  Mandya
# ...

# %%
weather.apply(pd.isnull).sum()/weather.shape[0]
# Out:
# YEAR           0.0
# DOY            0.0
# T2M            0.0
# T2MDEW         0.0
# T2M_MAX        0.0
# T2M_MIN        0.0
# RH2M           0.0
# PRECTOTCORR    0.0
# WS2M           0.0
# WS2M_MAX       0.0
# WS2M_MIN       0.0
# GWETTOP        0.0
# Place          0.0
# dtype: float64

# %%
core_column=["YEAR", "DOY", "T2M", "T2MDEW", "T2M_MAX", "T2M_MIN", "RH2M", "PRECTOTCORR", "WS2M", "WS2M_MAX", "WS2M_MIN", "Place"]
core_weather = weather[core_column]

# %%
core_weather
# Out:
#       YEAR  DOY     T2M  T2MDEW  T2M_MAX  T2M_MIN    RH2M  PRECTOTCORR  \
# 0     2001    6   21.28   12.01    30.22    15.45   63.25         0.00
# 1     2001    7   20.63   12.01    29.75    13.65   64.31         0.00
# 2     2001    8   20.81   12.02    29.36    14.08   63.75         0.00
# 3     2001    9   22.18   14.13    30.12    15.39   65.56         0.00
# 4     2001   10   22.83   15.27    30.69    16.46   66.31         0.00
# ...    ...  ...     ...     ...      ...      ...     ...          ...
# 8726  2024  332   21.12   19.08    25.68    17.75   88.88         0.15
# 8727  2024  333   19.98   16.70    26.01    16.19   82.62         1.54
# 8728  2024  334 -999.00 -999.00  -999.00  -999.00 -999.00      -999.00
# 8729  2024  335 -999.00 -999.00  -999.00  -999.00 -999.00      -999.00
# 8730  2024  336 -999.00 -999.00  -999.00  -999.00 -999.00      -999.00
#
#         WS2M  WS2M_MAX  WS2M_MIN   Place
# 0       2.34      3.80      1.30  Mandya
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#visulizationn of features
features_column = ["T2M", "T2MDEW", "T2M_MAX", "T2M_MIN", "RH2M", "PRECTOTCORR", "WS2M", "WS2M_MAX", "WS2M_MIN"]
plt.figure(figsize=(15, 10))
core_weather[features_column].hist(bins=20, range=(0, 100), color='blue', alpha=0.7, edgecolor='black')
plt.tight_layout()
plt.show()
#correlation b/w feeatures
correlation_matrix = core_weather[features_column].corr()
plt.figure(figsize=(15, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("Correlation of features")
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_featuers = scaler.fit_transform(core_weather[features_column])
core_weather_scaled = pd.DataFrame(scaled_featuers, columns=features_column)

#spliting data into training and testing set
x = core_weather_scaled.drop(["PRECTOTCORR"],axis=1)
y = core_weather_scaled[["PRECTOTCORR"]]
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2, random_state=42)

print("shape of x_train:", x_train.shape)
print("shape of x_test:", x_test.shape)
print("shape of y_train:", y_train.shape)
print("shape of y_test:", y_test.shape)
# Out:
# shape of x_train: (6984, 8)
# shape of x_test: (1747, 8)
# shape of y_train: (6984, 1)
# shape of y_test: (1747, 1)
